# %%
# %cd /yolov5

# !python detect.py --source='../data/sample3.mp4' --weights='../models/best.pt' --conf=0.5
# Out:
# [Errno 2] No such file or directory: '/yolov5'
# /content/drive/MyDrive/truck/yolov5
# detect: weights=['../models/best.pt'], source=../data/sample3.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients
# video 1/1 (1/913) /content/drive/MyDrive/truck/data/sample3.mp4: 448x640 (no detections), 308.0ms
# video 1/1 (2/913) /content/drive/MyDrive/truck/data/sample3.mp4: 448x640 (no detections), 304.0ms
# video 1/1 (3/913) /content/drive/MyDrive/truck/data/sample3.mp4: 448x640 (no detections), 298.1ms
# ...

# %%
import shutil
src = './runs/detect/exp/sample3.mp4'
dir = '../results'

# %%
shutil.move(src,dir)
# Out:
# '../results/sample3.mp4'
